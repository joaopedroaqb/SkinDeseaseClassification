# %%
import matplotlib.pyplot as plt

# Resultados do treinamento e validação
treinamento_perda = [1.82497, 1.33886, 1.07551, 0.93957, 0.84793, 0.76386, 0.67220, 0.65743, 0.63674, 0.58697, 0.54340, 0.51354, 0.46809, 0.44570, 0.42356, 0.38890, 0.38597, 0.35967, 0.35670, 0.31773]
treinamento_precisao = [0.366155, 0.530215, 0.618946, 0.668534, 0.705921, 0.730553, 0.775150, 0.756822, 0.784486, 0.784162, 0.795568, 0.829683, 0.843954, 0.844555, 0.837937, 0.883291, 0.870970, 0.881341, 0.882857, 0.905973]

validacao_perda = [1.52318, 1.07656, 0.87031, 0.78194, 0.70355, 0.60901, 0.53057, 0.56482, 0.47939, 0.45602, 0.38304, 0.34034, 0.31273, 0.31896, 0.31105, 0.23652, 0.18091, 0.19440, 0.14440, 0.14048]
validacao_precisao = [0.537333, 0.663639, 0.720928, 0.754774, 0.774749, 0.841585, 0.843758, 0.825955, 0.827692, 0.845495, 0.900610, 0.914068, 0.922313, 0.911462, 0.902348, 0.949653, 0.974397, 0.946612, 0.989159, 0.978307]

# Épocas
epocas = list(range(1, 21))

# Criando o gráfico
plt.figure(figsize=(10, 5))

# Subplot para Perda
plt.subplot(1, 2, 1)
plt.plot(epocas, treinamento_perda, label='Treinamento')
plt.plot(epocas, validacao_perda, label='Validação')
plt.xlabel('Épocas')
plt.ylabel('Perda')
plt.title('Perda durante o Treinamento e Validação')
plt.legend()

# Subplot para Precisão
plt.subplot(1, 2, 2)
plt.plot(epocas, treinamento_precisao, label='Treinamento')
plt.plot(epocas, validacao_precisao, label='Validação')
plt.xlabel('Épocas')
plt.ylabel('Precisão')
plt.title('Precisão durante o Treinamento e Validação')
plt.legend()

plt.tight_layout()
plt.show()
